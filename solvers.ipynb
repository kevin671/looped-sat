# %% [markdown]
# ## Setup

# %%
from dimacs_to_data import parse_dimacs

input_file = "inputs/example.dimacs"
n_vars, iclauses = parse_dimacs(input_file)
print(n_vars)
print(iclauses)
# Out:
# 5
# [[-4, -3, 1], [3, -1, 2], [4, 2, 3, -5, -1], [3, -5, 2, 1, 4], [-4, 1, 3, -5], [-4, -5, 1], [4, -2, -1, 5], [1, 5, -4], [-2, 1], [-1, 3, -2, -5, -4], [-3, 5, 2], [2, -5], [5, 4, 1, -2, 3], [4, -1, 3, 5, 2], [-2, 4, -1], [3, 2, 4], [1, -5, -2, 3], [2, 5, 1, 3], [4, 3, -1], [3, -5, -1, 4, 2], [5, 1, -2], [2, -1], [2, -1, 4], [-5, -4], [-1, -3, -5, 4, -2], [-5, -4, -3, -2, -1], [-3, -5, 1, 4, -2], [-2, -1, 3, 4], [5, -2, -3, 4, -1], [1, 3, -5, 2], [-1, 5, -4]]

# %% [markdown]
# ## DPLL

# %% [markdown]
# ## CDCL
