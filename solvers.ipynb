# %%
from dimacs_to_data import parse_dimacs

input_file = "inputs/example.dimacs"
n_vars, iclauses = parse_dimacs(input_file)
# Out:
# Running cells with 'loopsat (Python 3.11.11)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n loopsat ipykernel --update-deps --force-reinstall'

# %% [markdown]
# # DPLL

# %% [markdown]
# # CDCL
